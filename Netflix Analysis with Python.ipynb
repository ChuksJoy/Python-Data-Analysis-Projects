# %% [markdown]
# ### Netflix Dataset
#
# The Netflix dataset has information about the TV shows and Movies available on Netflix till 2021
#
# The dataset is collected from Flixable which is a third-party Netflix search engine and available on Kaggle
#
# For this we will using Pandas df to answer the questions below.
#
# This is the last of 8 simple data analysis project with pandas provided by [Data Science Lover](https://www.youtube.com/@data_science_lovers) on Youtube. can find other projects [here](https://www.youtube.com/playlist?list=PLy3lFw0OTlutzXFVwttrtaRGEEyLEdnpy)

# %%
# importing our Pandas library 

import pandas as pd

# %%
# will name the dataset 'nd' and import the dataset

nd = pd.read_csv('Netflix Dataset.csv')

# %%
nd.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...

# %% [markdown]
# ### Some basic  analysis to understand our dataset

# %%
nd.tail() # show the bottom 5
# Out:
#      Show_Id Category                                    Title     Director  \
# 7784   s7783    Movie                                     Zozo  Josef Fares
# 7785   s7784    Movie                                   Zubaan  Mozez Singh
# 7786   s7785    Movie                        Zulu Man in Japan          NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                            Nasty C
# 7787                         Adriano Zumbo, Rachel Khoo
# 7788                                                NaN
#
#                                                 Country        Release_Date  \
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# ...

# %%
nd.shape # show the number of rows and column
# Out:
# (7789, 11)

# %%
# total number of elements in the dataset

nd.size
# Out:
# 85679

# %%
# show the column names

nd.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
# datatype of the columns

nd.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
# all information about the dataset
nd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
# Show_Id         7789 non-null object
# Category        7789 non-null object
# Title           7789 non-null object
# Director        5401 non-null object
# Cast            7071 non-null object
# Country         7282 non-null object
# Release_Date    7779 non-null object
# Rating          7782 non-null object
# Duration        7789 non-null object
# Type            7789 non-null object
# Description     7789 non-null object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %% [markdown]
# #### Task. 1) Is there any Duplicate Record in this dataset ? If yes, then remove the duplicate records.

# %%
nd[nd.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
# remove duplicates

nd.drop_duplicates()
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
# make the removal of duplicates permanent with inplace
nd.drop_duplicates(inplace = True)

# %%
# check for duplicates again
nd[nd.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %% [markdown]
# #### Task. 2) Is there any Null Value present in any column ? Show with Heat-map.

# %%
# checking for null values count

nd.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
# importing the seanorn library for visualization

import seaborn as sns

# %%
sns.heatmap(nd.isnull());

# %% [markdown]
# #### Q. 1) For 'House of Cards', what is the Show Id and Who is the Director of this show ?

# %%
# using the isin function or str.contain function

nd['Title']
# Out:
# 0                                            3%
# 1                                         07:19
# 2                                         23:59
# 3                                             9
# 4                                            21
#                          ...
# 7784                                       Zozo
# 7785                                     Zubaan
# 7786                          Zulu Man in Japan
# 7787                      Zumbo's Just Desserts
# 7788    ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
# Name: Title, Length: 7787, dtype: object

# %%
nd[nd['Title'].isin(['House of Cards'])]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
# using str,contain function
nd[nd['Title'].str.contains('House of Cards')]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [markdown]
# #### Q. 2) In which year the highest number of the TV Shows & Movies were released ? Show with Bar Graph.

# %%
# checking the datatype of the release date column

nd.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
# since its an object datatype,, changing it to datetime using to_datetime function

nd['Release_Year'] = pd.to_datetime(nd['Release_Date'])

# %%
nd.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date            object
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# Release_Year    datetime64[ns]
# dtype: object

# %%
# using value count function to answer the question

nd['Release_Year'].dt.year.value_counts()
# Out:
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2009.0       2
# 2008.0       2
# 2010.0       1
# Name: Release_Year, dtype: int64

# %% [markdown]
# 2019 has the highest number of release of movies and tv shows

# %% [markdown]
# #### Q. 3) How many Movies & TV Shows are in the dataset ? Show with Bar Graph.

# %%
# using the release year column to visualize the number of movies and tv shows

nd['Release_Year'].dt.year.value_counts().plot(kind='bar');

# %%
# a piechart representation
nd['Release_Year'].dt.year.value_counts().plot(kind='pie');

# %%
# using the groupby function by category count

nd.groupby('Category').Category.count()
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %%
#visualizing by category

nd.groupby('Category').Category.count().plot(kind= 'bar');

# %%
# countplot function in seaborn library

sns.countplot(nd['Category']);

# %% [markdown]
# #### Q. 4) Show all the Movies that were released in year 2000.

# %%
# extract the year from the datetime column

nd['Year'] = nd['Release_Year'].dt.year

# %%
nd.head(3)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...     Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
#
#                                          Description Release_Year    Year
# ...

# %%
# answering the question of number of movies released in 2000

nd [(nd['Category'] == 'Movie') & (nd['Year']== 2000)]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Release_Year, Year]
# Index: []

# %% [markdown]
# No movies was released in the year 2000

# %%
# checking for other years
nd [(nd['Category'] == 'Movie') & (nd['Year']== 2021)]
# Out:
#      Show_Id Category                        Title             Director  \
# 57       s58    Movie                   100% Halal        Jastis Arimba
# 72       s73    Movie                     17 Again          Burr Steers
# 104     s105    Movie           30 Minutes or Less      Ruben Fleischer
# 205     s206    Movie              A Monster Calls          J.A. Bayona
# 366     s367    Movie                    Al acecho  Francisco D'Eufemia
# ...      ...      ...                          ...                  ...
# 7353   s7352    Movie                      Unknown   Jaume Collet-Serra
# 7553   s7552    Movie    What Happened to Mr. Cha?         Kim Dong-kyu
# 7571   s7570    Movie  What Would Sophia Loren Do?        Ross Kauffman
# 7572   s7571    Movie  What's Eating Gilbert Grape      Lasse Hallström
# 7646   s7645    Movie                     Wish You          Sung Do-jun
#
#                                                    Cast  \
# ...

# %%
nd [(nd['Category'] == 'Movie') & (nd['Year']== 2018)]
# Out:
#      Show_Id Category                     Title          Director  \
# 2         s3    Movie                     23:59      Gilbert Chan
# 17       s18    Movie                    22-Jul   Paul Greengrass
# 19       s20    Movie                       '89               NaN
# 20       s21    Movie      ​​Kuch Bheege Alfaaz              Onir
# 21       s22    Movie              ​Goli Soda 2      Vijay Milton
# ...      ...      ...                       ...               ...
# 7765   s7764    Movie                     Zenda    Avadhoot Gupte
# 7770   s7769    Movie  Zindagi Kitni Haseen Hay     Anjum Shahzad
# 7773   s7772    Movie                      Zion        Floyd Russ
# 7778   s7777    Movie                  Zokkomon  Satyajit Bhatkal
# 7782   s7781    Movie                       Zoo      Shlok Sharma
#
#                                                    Cast  \
# 2     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 17    Anders Danielsen Lie, Jon Øigarden, Jonas Stra...
# ...

# %%
nd [(nd['Category'] == 'Movie') & (nd['Year']== 2016)]
# Out:
#      Show_Id Category                    Title  \
# 1         s2    Movie                    07:19
# 25       s26    Movie                 (T)ERROR
# 35       s36    Movie                #Rucker50
# 59       s60    Movie          1000 Rupee Note
# 62       s63    Movie               13 Cameras
# ...      ...      ...                      ...
# 7715   s7714    Movie  Yo-Kai Watch: The Movie
# 7716   s7715    Movie              Yoga Hosers
# 7728   s7727    Movie             You Carry Me
# 7739   s7738    Movie              Young Tiger
# 7772   s7771    Movie                  Zinzana
#
#                                     Director  \
# 1                          Jorge Michel Grau
# 25    Lyric R. Cabral, David Felix Sutcliffe
# 35                     Robert McCullough Jr.
# 59                            Shrihari Sathe
# 62                            Victor Zarcoff
# ...                                      ...
# 7715                             Mark Risley
# ...

# %% [markdown]
# #### Q. 5) Show only the Titles of all TV Shows that were released in India only.

# %%
# first filter category for TV shows and then country for India and show only the Title

nd [(nd['Category'] == 'TV Show') & (nd['Country']== 'India')]['Title']
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                           Akbar Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %% [markdown]
# #### Q. 5b) Show only the Titles of all TV Shows that were released in Nigeria only.

# %%
nd [(nd['Category'] == 'TV Show') & (nd['Country']== 'Nigeria')]['Title']
# Out:
# 805                 Before 30
# 1238        Castle and Castle
# 1525      Crazy, Lovely, Cool
# 2156        Fifty: The Series
# 4596         Ojos in d' House
# 4616              On the Real
# 5722    Sons of the Caliphate
# 6414             The Governor
# Name: Title, dtype: object

# %% [markdown]
# #### Q. 6) Show Top 10 Directors, who gave the highest number of TV Shows & Movies to Netflix ?

# %%
# filtering by directors and value count 

nd['Director'].value_counts()
# Out:
# Raúl Campos, Jan Suter                         18
# Marcus Raboy                                   16
# Jay Karas                                      14
# Cathy Garcia-Molina                            13
# Jay Chapman                                    12
#                                                ..
# Marco Bonfanti                                  1
# Hugues Nancy, Fabien Beziat                     1
# Simon Verhoeven                                 1
# Aitor Arregi, Jon Garaño, Jose Mari Goenaga     1
# Digo Ricio                                      1
# Name: Director, Length: 4050, dtype: int64

# %%
# to see the top 10

nd['Director'].value_counts().head(10)
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Quentin Tarantino          8
# Name: Director, dtype: int64

# %%
# to see the last 10

nd['Director'].value_counts().tail(10)
# Out:
# Denis Hennelly, Casey Suchan                   1
# Rudy Soedjarwo                                 1
# Carlos Vermut                                  1
# Marco Risi                                     1
# Shashanka Ghosh, Samit Basu                    1
# Marco Bonfanti                                 1
# Hugues Nancy, Fabien Beziat                    1
# Simon Verhoeven                                1
# Aitor Arregi, Jon Garaño, Jose Mari Goenaga    1
# Digo Ricio                                     1
# Name: Director, dtype: int64

# %% [markdown]
# #### Q. 7) Show all the Records, where "Category is Movie and Type is Comedies" or "Country is United Kingdom".

# %%
# we will filter by category and use the And & Or operator

nd[(nd['Category']== 'Movie') & (nd['Type']== 'Comedies')]
# Out:
#      Show_Id Category                        Title                Director  \
# 33       s34    Movie                 #realityhigh        Fernando Lebrija
# 72       s73    Movie                     17 Again             Burr Steers
# 84       s85    Movie                    21 & Over  Jon Lucas, Scott Moore
# 148     s149    Movie         A Bad Moms Christmas  Jon Lucas, Scott Moore
# 174     s175    Movie  A Futile and Stupid Gesture              David Wain
# ...      ...      ...                          ...                     ...
# 7341   s7340    Movie         Undercover Brother 2            Leslie Small
# 7590   s7589    Movie            Where's the Money         Scott Zabielski
# 7623   s7622    Movie                    Wild Oats            Andy Tennant
# 7634   s7633    Movie                 Wine Country             Amy Poehler
# 7664   s7663    Movie                      Work It           Laura Terruso
#
#                                                    Cast  \
# ...

# %%
# using the Or operator to add the second condition

nd[(nd['Category']== 'Movie') & (nd['Type']== 'Comedies')|(nd['Country']== 'United Kingdom')]
# Out:
#      Show_Id Category                   Title          Director  \
# 19       s20    Movie                     '89               NaN
# 33       s34    Movie            #realityhigh  Fernando Lebrija
# 58       s59  TV Show             100% Hotter               NaN
# 72       s73    Movie                17 Again       Burr Steers
# 82       s83    Movie     2036 Origin Unknown     Hasraf Dulull
# ...      ...      ...                     ...               ...
# 7670   s7669  TV Show  World War II in Colour               NaN
# 7671   s7670  TV Show  World's Busiest Cities               NaN
# 7688   s7687    Movie  XV: Beyond the Tryline  Pierre Deschamps
# 7725   s7724    Movie            You Can Tutu       James Brown
# 7740   s7739  TV Show         Young Wallander               NaN
#
#                                                    Cast         Country  \
# 19                   Lee Dixon, Ian Wright, Paul Merson  United Kingdom
# ...

# %% [markdown]
# This satisfies both condition wither the country is United kingdom or the type of the movie is comedy

# %% [markdown]
# #### Q. 8) In how many movies/shows, Tom Cruise was cast ?

# %%
nd.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
nd['Cast'].str.contains('Tom Cruise')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7784    False
# 7785    False
# 7786    False
# 7787    False
# 7788      NaN
# Name: Cast, Length: 7787, dtype: object

# %%
# remove the null values in the dataframe by first creating a new dataframe and the drop all null values

nd1 = nd.dropna()

# %%
nd1.head(3)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
#
#                                                 Cast        Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
#
#         Release_Date Rating Duration  \
# 1  December 23, 2016  TV-MA   93 min
# 2  December 20, 2018      R   78 min
# 3  November 16, 2017  PG-13   80 min
#
#                                                 Type  \
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
# 3  Action & Adventure, Independent Movies, Sci-Fi...
#
#                                          Description Release_Year    Year
# ...

# %%
nd1[nd1['Cast'].str.contains('Tom Cruise')]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date Rating Duration                        Type  \
# 3860  January 1, 2020      R  189 min  Dramas, Independent Movies
# 5071     July 1, 2019      R  134 min      Classic Movies, Dramas
#
#                                             Description Release_Year    Year
# 3860  Through chance, human action, past history and...   2020-01-01  2020.0
# 5071  A fast-talking yuppie is forced to slow down w...   2019-07-01  2019.0

# %% [markdown]
# #### Q. 9) What are the different Ratings defined by Netflix ?

# %%
# using nunique function

nd.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description Release_Year    Year
# 0  In a future where the elite inhabit an island ...   2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit...   2016-12-23  2016.0

# %%
nd['Rating'].nunique()
# Out:
# 14

# %%
#There are 14 defferent ratings defined by netflix
# to view the ratings

nd['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# #### Q. 9.1) How many Movies got the 'TV-14' rating, in Canada ?

# %%
# filter the category column and the ratings for tv-14

nd [(nd['Category']=="Movie") & (nd['Rating']=='TV-14')]
# Out:
#      Show_Id Category                     Title            Director  \
# 8         s9    Movie                       706       Shravan Kumar
# 15       s16    Movie                    Oct-01      Kunle Afolayan
# 18       s19    Movie                    15-Aug  Swapnaneel Jayakar
# 20       s21    Movie      ​​Kuch Bheege Alfaaz                Onir
# 21       s22    Movie              ​Goli Soda 2        Vijay Milton
# ...      ...      ...                       ...                 ...
# 7765   s7764    Movie                     Zenda      Avadhoot Gupte
# 7766   s7765    Movie                      Zero          Aanand Rai
# 7770   s7769    Movie  Zindagi Kitni Haseen Hay       Anjum Shahzad
# 7771   s7770    Movie  Zindagi Na Milegi Dobara         Zoya Akhtar
# 7785   s7784    Movie                    Zubaan         Mozez Singh
#
#                                                    Cast   Country  \
# 8     Divya Dutta, Atul Kulkarni, Mohan Agashe, Anup...     India
# ...

# %%
# show the count using shape 

nd [(nd['Category']=="Movie") & (nd['Rating']=='TV-14')].shape
# Out:
# (1272, 13)

# %%
# filtering county for Canada

nd [(nd['Category']=="Movie") & (nd['Rating']=='TV-14') & (nd['Country']== 'Canada')]
# Out:
#      Show_Id Category                                        Title  \
# 30       s31    Movie                             #cats_the_mewvie
# 34       s35    Movie                                        #Roxy
# 608     s609    Movie                               At First Light
# 1506   s1507    Movie                   Counterfeiting in Suburbia
# 3713   s3714    Movie                            Long Time Running
# 3956   s3957    Movie  Martin Matte: La vie, la mort...eh la la..!
# 5336   s5336    Movie                   Sadie's Last Days on Earth
# 5393   s5393    Movie                                   Sardaar ji
# 6062   s6062    Movie                  The Accountant of Auschwitz
# 7025   s7024    Movie                         The Wrong Babysitter
# 7041   s7040    Movie               There's Something in the Water
#
#                                     Director  \
# 30                          Michael Margolis
# 34                           Michael Kennedy
# ...

# %% [markdown]
# #### Q. 9.1b) How many Movies got the 'TV-14' rating, in Nigeria ?

# %%
nd [(nd['Category']=="Movie") & (nd['Rating']=='TV-14') & (nd['Country']== 'Nigeria')]
# Out:
#      Show_Id Category                                   Title  \
# 15       s16    Movie                                  Oct-01
# 713     s714    Movie                     Banana Island Ghost
# 820     s821    Movie                        Being Mrs Elliot
# 1456   s1457    Movie                               Cold Feet
# 1509   s1510    Movie                          Couple of Days
# 2581   s2582    Movie                                Hakkunde
# 2966   s2967    Movie                                 In Line
# 3070   s3071    Movie                                  Isoken
# 3312   s3313    Movie                                Kasanova
# 3636   s3637    Movie                       Light in the Dark
# 3761   s3762    Movie                             Love Is War
# 4166   s4167    Movie                      Mokalik (Mechanic)
# 4171   s4172    Movie                             Moms at War
# 4452   s4453    Movie                               New Money
# ...

# %%
nd [(nd['Category']=="Movie") & (nd['Rating']=='TV-14') & (nd['Country']== 'Canada')].shape
# Out:
# (11, 13)

# %% [markdown]
# #### Q. 9.2) How many TV Shows got the 'R' rating, after year 2018 ?

# %%
nd [(nd['Category']=="TV Show") & (nd['Rating']=='R')]
# Out:
#      Show_Id Category                                Title           Director  \
# 4497   s4498  TV Show                                Nobel                NaN
# 6437   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country  \
# 4497  Aksel Hennie, Tuva Novotny, Anders Danielsen L...  Norway
# 6437  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN
#
#            Release_Date Rating  Duration  \
# 4497  December 10, 2016      R  1 Season
# 6437     April 25, 2019      R  1 Season
#
#                                                  Type  \
# 4497  International TV Shows, TV Dramas, TV Thrillers
# 6437                                         TV Shows
#
#                                             Description Release_Year    Year
# 4497  A series of incidents in Afghanistan set compl...   2016-12-10  2016.0
# 6437  Trapped at a stagecoach stop as a storm rages ...   2019-04-25  2019.0

# %%
nd [(nd['Category']=="TV Show") & (nd['Rating']=='R') & (nd['Year'] > 2018)]
# Out:
#      Show_Id Category                                Title           Director  \
# 6437   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country  \
# 6437  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN
#
#         Release_Date Rating  Duration      Type  \
# 6437  April 25, 2019      R  1 Season  TV Shows
#
#                                             Description Release_Year    Year
# 6437  Trapped at a stagecoach stop as a storm rages ...   2019-04-25  2019.0

# %% [markdown]
# #### Q. 10) What is the maximum duration of a Movie/Show on Netflix ?

# %%
nd.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description Release_Year    Year
# 0  In a future where the elite inhabit an island ...   2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit...   2016-12-23  2016.0

# %%
# from the duration column we can see there are differnt types of duration

nd['Duration'].unique()
# Out:
# array(['4 Seasons', '93 min', '78 min', '80 min', '123 min', '1 Season',
#        '95 min', '119 min', '118 min', '143 min', '103 min', '89 min',
#        '91 min', '149 min', '144 min', '124 min', '87 min', '110 min',
#        '128 min', '117 min', '100 min', '2 Seasons', '84 min', '99 min',
#        '90 min', '102 min', '104 min', '105 min', '56 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '109 min', '44 min',
#        '75 min', '101 min', '3 Seasons', '37 min', '113 min', '114 min',
#        '130 min', '94 min', '140 min', '135 min', '82 min', '70 min',
#        '121 min', '92 min', '164 min', '53 min', '83 min', '116 min',
#        '86 min', '120 min', '96 min', '126 min', '129 min', '77 min',
#        '137 min', '148 min', '28 min', '122 min', '176 min', '85 min',
#        '22 min', '68 min', '111 min', '29 min', '142 min', '168 min',
#        '21 min', '59 min', '20 min', '98 min', '108 min', '76 min',
# ...

# %% [markdown]
# Some durations are in minutes while some are in seasons

# %%
# checking the datatype of the duration column
nd['Duration'].dtypes
# Out:
# dtype('O')

# %%
# Spliting the elements of the duration columns to two different columns for the numeric and the categorical values

nd[['Minutes', 'Units']] = nd['Duration'].str.split(' ', expand = True)

# %%
nd.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description Release_Year    Year  \
# 0  In a future where the elite inhabit an island ...   2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit...   2016-12-23  2016.0
#
#   Minutes    Units
# 0       4  Seasons
# 1      93      min

# %% [markdown]
# Two columns units and minutes have been created using str.split to split the duration column

# %%
# the values of the minutes column

nd.Minutes
# Out:
# 0         4
# 1        93
# 2        78
# 3        80
# 4       123
#        ...
# 7784     99
# 7785    111
# 7786     44
# 7787      1
# 7788     90
# Name: Minutes, Length: 7787, dtype: object

# %%
# to find the maximum values

nd['Minutes'].max()
# Out:
# '99'

# %%
# to find the minimum

nd['Minutes'].min()
# Out:
# '1'

# %% [markdown]
# #### Q. 11) Which individual country has the Highest No. of TV Shows ?

# %%
# we will consider the category and country columns
# first create a new dataframe to contain only the tv shows

nd_tvshows = nd[nd['Category'] == "TV Show"]

# %%
# to view the new dataframe

nd_tvshows.head(2)
# Out:
#   Show_Id Category Title     Director  \
# 0      s1  TV Show    3%          NaN
# 5      s6  TV Show    46  Serdar Akar
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...  Turkey     July 1, 2017
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 5  TV-MA   1 Season    International TV Shows, TV Dramas, TV Mysteries
#
#                                          Description Release_Year    Year  \
# 0  In a future where the elite inhabit an island ...   2020-08-14  2020.0
# 5  A genetics professor experiments with a treatm...   2017-07-01  2017.0
#
#   Minutes    Units
# 0       4  Seasons
# 5       1   Season

# %%
# using value count function to get the result of tvshows in the country column

nd_tvshows['Country'].value_counts()
# Out:
# United States                                705
# United Kingdom                               204
# Japan                                        157
# South Korea                                  147
# India                                         71
#                                             ...
# United Kingdom, Singapore                      1
# Belgium, Netherlands                           1
# Canada, United States, Ireland                 1
# United States, France, Canada                  1
# South Korea, Canada, United States, China      1
# Name: Country, Length: 183, dtype: int64

# %%
# the county with the highest number of tvshows

nd_tvshows['Country'].value_counts().head(1)
# Out:
# United States    705
# Name: Country, dtype: int64

# %% [markdown]
# The United States is the individual country with the highest number of TV Shows

# %% [markdown]
# #### Q. 12) How can we sort the dataset by Year ?

# %%
# sorting the dataframe by year using the sort_values function

nd.sort_values(by = 'Year')
# Out:
#      Show_Id Category                         Title              Director  \
# 7115   s7114    Movie          To and From New York  Sorin Dan Mihalcescu
# 1765   s1766  TV Show               Dinner for Five                   NaN
# 3248   s3249    Movie       Just Another Love Story          Ole Bornedal
# 5766   s5766    Movie                      Splatter             Joe Dante
# 3840   s3841    Movie   Mad Ron's Prevues from Hell            Jim Monaco
# ...      ...      ...                           ...                   ...
# 3374   s3375  TV Show                      Kikoriki                   NaN
# 3492   s3493  TV Show           La Familia P. Luche                   NaN
# 3946   s3947  TV Show                         Maron                   NaN
# 5138   s5138  TV Show                  Red vs. Blue                   NaN
# 6066   s6066  TV Show  The Adventures of Figaro Pho                   NaN
#
#                                                    Cast        Country  \
# ...

# %%
nd.sort_values(by = 'Year', ascending = False)
# Out:
#      Show_Id Category                         Title                 Director  \
# 5564   s5564    Movie               Sherlock Holmes              Guy Ritchie
# 5919   s5919    Movie                     Surf's Up  Ash Brannon, Chris Buck
# 980     s981  TV Show                  Bling Empire                      NaN
# 5955   s5955    Movie              Taare Zameen Par               Aamir Khan
# 366     s367    Movie                     Al acecho      Francisco D'Eufemia
# ...      ...      ...                           ...                      ...
# 3374   s3375  TV Show                      Kikoriki                      NaN
# 3492   s3493  TV Show           La Familia P. Luche                      NaN
# 3946   s3947  TV Show                         Maron                      NaN
# 5138   s5138  TV Show                  Red vs. Blue                      NaN
# 6066   s6066  TV Show  The Adventures of Figaro Pho                      NaN
#
# ...

# %% [markdown]
# #### Q. 13) Find all the instances where:
#
# #### Category is 'Movie' and Type is 'Dramas'
#
# #### or
#
# #### Category is 'TV Show' & Type is 'Kids' TV'.

# %%
# filter by category

nd[ (nd['Category']== 'Movie') & (nd['Type'] == 'Dramas')].head(3)
# Out:
#     Show_Id Category         Title        Director  \
# 4        s5    Movie            21  Robert Luketic
# 7        s8    Movie           187  Kevin Reynolds
# 170    s171    Movie  A Family Man   Mark Williams
#
#                                                   Cast                Country  \
# 4    Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...          United States
# 7    Samuel L. Jackson, John Heard, Kelly Rowan, Cl...          United States
# 170  Gerard Butler, Gretchen Mol, Alison Brie, Will...  Canada, United States
#
#           Release_Date Rating Duration    Type  \
# 4      January 1, 2020  PG-13  123 min  Dramas
# 7     November 1, 2019      R  119 min  Dramas
# 170  December 15, 2019      R  110 min  Dramas
#
#                                            Description Release_Year    Year  \
# 4    A brilliant group of students become card-coun...   2020-01-01  2020.0
# 7    After one of his high school students attacks ...   2019-11-01  2019.0
# ...

# %%
nd[ (nd['Category']== 'TV Show') & (nd['Type'] == "Kids' TV")].head(3)
# Out:
#     Show_Id Category         Title     Director  \
# 111    s112  TV Show       44 Cats          NaN
# 276    s277  TV Show  Abby Hatcher  Kyran Kelly
# 434    s435  TV Show   Alphablocks          NaN
#
#                                                   Cast                Country  \
# 111  Sarah Natochenny, Suzy Myers, Simona Berman, E...                  Italy
# 276  Macy Drouin, Wyatt White, Paul Sun-Hyung Lee, ...  United States, Canada
# 434    Teresa Gallagher, David Holt, Lizzie Waterworth         United Kingdom
#
#         Release_Date Rating   Duration      Type  \
# 111  October 1, 2020  TV-Y7  2 Seasons  Kids' TV
# 276     July 1, 2020   TV-Y   1 Season  Kids' TV
# 434     May 25, 2020   TV-Y  5 Seasons  Kids' TV
#
#                                            Description Release_Year    Year  \
# 111  Paw-esome tales abound when singing furry frie...   2020-10-01  2020.0
# 276  A big-hearted girl helps her Fuzzly friends wh...   2020-07-01  2020.0
# ...

# %%
# combining both conditions using the or operator

nd[ (nd['Category']== 'Movie') & (nd['Type'] == 'Dramas') | (nd['Category']== 'TV Show') & (nd['Type'] == "Kids' TV")]
# Out:
#      Show_Id Category                       Title        Director  \
# 4         s5    Movie                          21  Robert Luketic
# 7         s8    Movie                         187  Kevin Reynolds
# 111     s112  TV Show                     44 Cats             NaN
# 170     s171    Movie                A Family Man   Mark Williams
# 232     s233    Movie  A Stoning in Fulham County   Larry Elikann
# ...      ...      ...                         ...             ...
# 7668   s7667  TV Show               World of Winx  Iginio Straffi
# 7717   s7716  TV Show                        Yoko             NaN
# 7719   s7718  TV Show                         YOM             NaN
# 7758   s7757  TV Show                          Z4             NaN
# 7761   s7760  TV Show                   Zak Storm             NaN
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 7     Samuel L. Jackson, John Heard, Kelly Rowan, Cl...
# ...

# %% [markdown]
# This satisfies both conditions, the first being movies and drama and the second TV Shows and Kids'TV
